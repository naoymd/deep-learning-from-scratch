# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %%
cd drive
# Out:
# /content/drive

# %%
# !ls
# Out:
# 'My Drive'

# %%
cd 'My Drive'
# Out:
# /content/drive/My Drive

# %%
# !ls
# Out:
# 'Colab Notebooks'   deep-learning-from-scratch-master   IMG_0001.pdf

# %%
cd deep-learning-from-scratch-master
# Out:
# /content/drive/My Drive/deep-learning-from-scratch-master

# %%
# !ls
# Out:
# ch01  ch03  ch05  ch07	common	 LICENSE.md
# ch02  ch04  ch06  ch08	dataset  README.md

# %%
cd ch08
# Out:
# /content/drive/My Drive/deep-learning-from-scratch-master/ch08
