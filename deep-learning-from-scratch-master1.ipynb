# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %%
cd drive
# Out:
# /content/drive

# %%
# !ls
# Out:
# 'My Drive'

# %%
cd 'My Drive'
# Out:
# /content/drive/My Drive

# %%
# !ls
# Out:
# 'Colab Notebooks'   deep-learning-from-scratch-master   IMG_0001.pdf

# %%
#cd 'Colab Notebooks'

# %%
#!pwd

# %%
#!ls

# %%
cd deep-learning-from-scratch-master
# Out:
# /content/drive/My Drive/deep-learning-from-scratch-master

# %%
# !ls
# Out:
#  ch01   ch05   common	   't10k-images-idx3-ubyte.gz のコピー'
#  ch02   ch06   dataset	   't10k-labels-idx1-ubyte.gz のコピー'
#  ch03   ch07   LICENSE.md  'train-images-idx3-ubyte.gz のコピー'
#  ch04   ch08   README.md   'train-labels-idx1-ubyte.gz のコピー'

# %%
cd ch01
# Out:
# /content/drive/My Drive/deep-learning-from-scratch-master/ch01

# %%
# !pwd
# Out:
# /content/drive/My Drive/deep-learning-from-scratch-master/ch01

# %%
# !ls
# Out:
# hungry.py  img_show.py	man.py	simple_graph.py  sin_cos_graph.py  sin_graph.py

# %%
1 - 2
# Out:
# -1

# %%
4 * 5
# Out:
# 20

# %%
7 / 5
# Out:
# 1.4

# %%
3 ** 2
# Out:
# 9

# %%
type(10)
# Out:
# int

# %%
type(2.718)
# Out:
# float

# %%
type("hello")
# Out:
# str

# %%
x = 10 #初期化
print(x) #xを出力する
# Out:
# 10

# %%
x = 100 #代入
print(x)
# Out:
# 100

# %%
y = 3.14
x*y
# Out:
# 314.0

# %%
type(x * y)
# Out:
# float

# %%
a = [1,2,3,4,5] #リストの作成
print(a) #リストの中身を出力する
# Out:
# [1, 2, 3, 4, 5]

# %%
len(a) #リストの長さを取得
# Out:
# 5

# %%
a[0] #最初の要素にアクセス
# Out:
# 1

# %%
a[4] #値を代入
# Out:
# 5

# %%
a[4] = 99
print(a)
# Out:
# [1, 2, 3, 4, 99]

# %%
print(a)
# Out:
# [1, 2, 3, 4, 99]

# %%
a[0:2] #インデックスの0番目から2番目(2番目は含まない!)まで取得
# Out:
# [1, 2]

# %%
a[1:] #インデックスの1番目から最後まで取得
# Out:
# [2, 3, 4, 99]

# %%
a[:3] #最初からインデックスの3番目(3番目は含まない!)まで取得
# Out:
# [1, 2, 3]

# %%
a[:-1] #最初から最後の要素のひとつ前まで取得
# Out:
# [1, 2, 3, 4]

# %%
a[:-2] #最初から最後の要素の2つ前まで取得
# Out:
# [1, 2, 3]

# %%
me = {'height':180} #ディクショナリを作成
me['height'] #要素にアクセス
# Out:
# 180

# %%
me['weight'] = 70 #新しい要素を追加
print(me)
# Out:
# {'height': 180, 'weight': 70}

# %%
hungry = True #お腹空いてる?
sleepy = False #眠い?
type(hungry)
# Out:
# bool

# %%
not hungry
# Out:
# False

# %%
hungry and sleepy #空腹 かつ 眠い
# Out:
# False

# %%
hungry or sleepy #空腹 または 眠い
# Out:
# True

# %%
hungry = True
if hungry:
  print("I'm hungry")
# Out:
# I'm hungry

# %%
hungry = False
if hungry:
    print("I'm hungry") #空白文字によるインデント
else:
    print("I'm not hungry")
    print("I'm sleepy")
# Out:
# I'm not hungry
# I'm sleepy

# %%
for i in [1,2,3]:
  print(i)
# Out:
# 1
# 2
# 3

# %%
def hello():
  print("Hello World!")

# %%
hello()
# Out:
# Hello World!

# %%
def hello(object):
  print("Hello " + object + "!")

# %%
hello("cat")
# Out:
# Hello cat!

# %%
#$ cd =/deep-learning-from-scratch/ch01 #ディレクトリの移動
python hungry.py
# Out:
#   File "<ipython-input-51-bfe66e6d21e5>", line 1
#     python hungry.py
#                 ^
# SyntaxError: invalid syntax

# %%
class Man:
  def __init__(self, name):
    self.name = name
    print("Initiaized!")
    
  def hello(self):
    print("Hello " + self.name + "!")
  def goodbye(self):
    print("Good-bye " + self.name + "!")

# %%
m = Man("David")
m.hello()
m.goodbye()

# %%
import numpy as np

# %%
x = np.array([1.0,2.0,3.0])
print(x)

# %%
type(x)
# Out:
# int

# %%
x = np.array([1.0,2.0,3.0])
y = np.array([2.0,4.0,6.0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-1ef815d11a5d> in <module>()
# ----> 1 x = np.array([1.0,2.0,3.0])
#       2 y = np.array([2.0,4.0,6.0])
#
# NameError: name 'np' is not defined

# %%
x + y #要素ごとの足し算
# Out:
# 103.14

# %%
x - y
# Out:
# 96.86

# %%
x * y #element-wise product(要素ごとの積)
# Out:
# 314.0

# %%
x / y
# Out:
# 31.84713375796178

# %%
A = np.array([[1,2],[3,4]])
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-bac3038fa5bc> in <module>()
# ----> 1 A = np.array([[1,2],[3,4]])
#       2 print(A)
#
# NameError: name 'np' is not defined

# %%
A.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-d5a4efdcb733> in <module>()
# ----> 1 A.shape
#
# NameError: name 'A' is not defined

# %%
A.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-39fb59b1638a> in <module>()
# ----> 1 A.dtype
#
# NameError: name 'A' is not defined

# %%
B = np.array([[3,0],[0,6]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-263b26df8534> in <module>()
# ----> 1 B = np.array([[3,0],[0,6]])
#
# NameError: name 'np' is not defined

# %%
A + B
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-151064de832d> in <module>()
# ----> 1 A + B
#
# NameError: name 'A' is not defined

# %%
A * B
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-a4cedde81ed0> in <module>()
# ----> 1 A * B
#
# NameError: name 'A' is not defined

# %%
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-939330b76721> in <module>()
# ----> 1 print(A)
#
# NameError: name 'A' is not defined

# %%
A * 10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-5ac7e950a157> in <module>()
# ----> 1 A * 10
#
# NameError: name 'A' is not defined

# %%
A = np.array([[1,2],[3,4]])
B = np.array([10,20])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-b7ef13eedaaa> in <module>()
# ----> 1 A = np.array([[1,2],[3,4]])
#       2 B = np.array([10,20])
#
# NameError: name 'np' is not defined

# %%
A * B
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-a4cedde81ed0> in <module>()
# ----> 1 A * B
#
# NameError: name 'A' is not defined

# %%
X = np.array([[51,55],[14,19],[0,4]])
print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-22f45524d04f> in <module>()
# ----> 1 X = np.array([[51,55],[14,19],[0,4]])
#       2 print(X)
#
# NameError: name 'np' is not defined

# %%
X[0] #0行目
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-79de4a0356ea> in <module>()
# ----> 1 X[0] #0行目
#
# NameError: name 'X' is not defined

# %%
X[0][1] #(0,1)の要素
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-a1afc015b8fc> in <module>()
# ----> 1 X[0][1] #(0,1)の要素
#
# NameError: name 'X' is not defined

# %%
for row in X:
  print(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-2cbf14869fa4> in <module>()
# ----> 1 for row in X:
#       2   print(row)
#
# NameError: name 'X' is not defined

# %%
X = X.flatten() #Xを1次元の配列へ変換
print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-e68c5f4fde72> in <module>()
# ----> 1 X = X.flatten() #Xを1次元の配列へ変換
#       2 print(X)
#
# NameError: name 'X' is not defined

# %%
X[np.array([0,2,4])] #インデックスが0,2,4番目の要素を取得
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-8e38aafc18b5> in <module>()
# ----> 1 X[np.array([0,2,4])] #インデックスが0,2,4番目の要素を取得
#
# NameError: name 'X' is not defined

# %%
X > 15

# %%
X[X > 15]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-a919f16df624> in <module>()
# ----> 1 X[X > 15]
#
# NameError: name 'X' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

#データの作成
x = np.arange(0,6,0.1) #0から6まで0.1刻みで生成
y = np.sin(x)

#グラフの描画
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#データの作成
x = np.arange(0,6,0.1) #0から6まで0.1刻みで生成
y1 = np.sin(x)
y2 = np.cos(x)

#グラフの描画
plt.plot(x,y1,label="sin")
plt.plot(x,y2,label="cos")
plt.xlabel("x") #x軸のラベル
plt.ylabel("y") #y軸のラベル
plt.title('sin & cos') #タイトル
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('../dataset/lena.png') #画像の読み込み(適切なパスを設定する!)
plt.imshow(img)

plt.show()

# %%
#cd /content
